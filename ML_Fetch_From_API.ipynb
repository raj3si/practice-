# %% [markdown]
# <a href="https://colab.research.google.com/github/raj3si/practice-/blob/fatching-from-api/ML_Fetch_From_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests

url = "https://moviesdatabase.p.rapidapi.com/titles/series/%7BseriesId%7D"

headers = {
	"X-RapidAPI-Key": "846f7f726bmsh8e00f43e37ea16ap1a5a5ajsne30f4bc4f4ca",
	"X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'results': []}

# %%
import requests

url = "https://moviesdatabase.p.rapidapi.com/titles/x/upcoming"

headers = {
	"X-RapidAPI-Key": "846f7f726bmsh8e00f43e37ea16ap1a5a5ajsne30f4bc4f4ca",
	"X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'page': 1, 'next': '/titles/x/upcoming?page=2', 'entries': 10, 'results': [{'_id': '61e58c6aef99b1c54343e375', 'id': 'tt10209920', 'primaryImage': {'id': 'rm882431489', 'width': 8200, 'height': 12300, 'url': 'https://m.media-amazon.com/images/M/MV5BNjc5ZGQwNjMtNGI3NC00Yzg3LTk4MjktMDgwYTcyZDhhNmRmXkEyXkFqcGdeQXVyMjE2MzA5MDI@._V1_.jpg', 'caption': {'plainText': 'Alien Wars: Judgement Day (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Alien Wars: Judgement Day', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Alien Wars: Judgement Day', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, 
# ...

# %%
pd.DataFrame(response.json()["results"])
# Out:
#                         _id          id  \
# 0  61e58c6aef99b1c54343e375  tt10209920
# 1  61e58cf6e1a8ddbd96440553  tt10300398
# 2  61e58d98ef99b1c543442d6b  tt10408218
# 3  61e58de9a66e596423444171  tt10461964
# 4  61e58e6b8a5a6a599f4461c3  tt10545296
# 5  61e58ea278c012aa34446beb  tt10579986
# 6  61e58ed0971a4a15d64478bf  tt10610440
# 7  61e58f32909c2ca781448fa9  tt10676048
# 8  61e58fbf95801a78bc44b441  tt10767052
# 9  61e590a2971a4a15d644ea71  tt10914400
#
#                                         primaryImage  \
# 0  {'id': 'rm882431489', 'width': 8200, 'height':...
# 1                                               None
# 2  {'id': 'rm3380222977', 'width': 1080, 'height'...
# 3                                               None
# 4  {'id': 'rm770462209', 'width': 1728, 'height':...
# 5  {'id': 'rm878544897', 'width': 1217, 'height':...
# 6  {'id': 'rm3466278913', 'width': 2282, 'height'...
# 7  {'id': 'rm4234500609', 'width': 1688, 'height'...
# ...

# %%
df=pd.DataFrame()

# %%
for i in range(1,10):
  url = f"https://moviesdatabase.p.rapidapi.com/titles/x/upcoming?page={i}"

  headers = {
    "X-RapidAPI-Key": "846f7f726bmsh8e00f43e37ea16ap1a5a5ajsne30f4bc4f4ca",
    "X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"}

  response = requests.get(url, headers=headers)
  temp_df=pd.DataFrame(response.json()["results"])
  df=df.append(temp_df,ignore_index=True)
# Out:
# <ipython-input-19-34864fb31546>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# <ipython-input-19-34864fb31546>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# <ipython-input-19-34864fb31546>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# <ipython-input-19-34864fb31546>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#                           _id          id  \
# 0    61e58c6aef99b1c54343e375  tt10209920
# 1    61e58cf6e1a8ddbd96440553  tt10300398
# 2    61e58d98ef99b1c543442d6b  tt10408218
# 3    61e58de9a66e596423444171  tt10461964
# 4    61e58e6b8a5a6a599f4461c3  tt10545296
# ..                        ...         ...
# 175  61e5a91478c012aa344afcd9  tt15126514
# 176  61e5a91495801a78bc4b0357  tt15126474
# 177  61e5a9b0d735dff3f94b28cf  tt15229258
# 178  61e5a9bf8a5a6a599f4b2dfb  tt15239640
# 179  61e5aa5f95801a78bc4b5627  tt15345172
#
#                                           primaryImage  \
# 0    {'id': 'rm882431489', 'width': 8200, 'height':...
# 1                                                 None
# 2    {'id': 'rm3380222977', 'width': 1080, 'height'...
# 3                                                 None
# 4    {'id': 'rm770462209', 'width': 1728, 'height':...
# ..                                                 ...
# 175  {'id': 'rm410963713', 'width': 3508, 'height':...
# ...

# %%
import requests

url = "https://moviesdatabase.p.rapidapi.com/titles"

headers = {
	"X-RapidAPI-Key": "846f7f726bmsh8e00f43e37ea16ap1a5a5ajsne30f4bc4f4ca",
	"X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'page': 1, 'next': '/titles?page=2', 'entries': 10, 'results': [{'_id': '61e57fd65c5338f43c777f4a', 'id': 'tt0000081', 'primaryImage': {'id': 'rm211543552', 'width': 226, 'height': 300, 'url': 'https://m.media-amazon.com/images/M/MV5BM2ZlYjA4NmItZTYxYy00MGFiLTg3MWUtNzZmYjE1ODZmMThjXkEyXkFqcGdeQXVyNTI2NTY2MDI@._V1_.jpg', 'caption': {'plainText': 'Les haleurs de bateaux (1896)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Les haleurs de bateaux', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Les haleurs de bateaux', '__typename': 'TitleText'}, 'releaseYear': {'year': 1896, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': None}, {'_id': '61e57fd65c5338f43c777f4c', 'id': 'tt0000045', 'primaryImage': {'id': 'rm362538496', 'width': 226, 'height': 300, 'url': 'https://m.media-amazon.com/images/M/MV5BNzBjZjI4YjYtNGIyOC00ZDQyLT
# ...

# %%
pd.DataFrame(response.json()["results"])
# Out:
#                         _id         id  \
# 0  61e57fd65c5338f43c777f4a  tt0000081
# 1  61e57fd65c5338f43c777f4c  tt0000045
# 2  61e57fd65c5338f43c777f4e  tt0000066
# 3  61e57fd65c5338f43c777f50  tt0000049
# 4  61e57fd65c5338f43c777f52  tt0000103
# 5  61e57fd65c5338f43c777f54  tt0000133
# 6  61e57fd65c5338f43c777f56  tt0000125
# 7  61e57fd65c5338f43c777f58  tt0000184
# 8  61e57fd65c5338f43c777f5a  tt0000109
# 9  61e57fd65c5338f43c777f5c  tt0000086
#
#                                         primaryImage  \
# 0  {'id': 'rm211543552', 'width': 226, 'height': ...
# 1  {'id': 'rm362538496', 'width': 226, 'height': ...
# 2  {'id': 'rm1117513216', 'width': 226, 'height':...
# 3  {'id': 'rm4062580736', 'width': 1280, 'height'...
# 4  {'id': 'rm597419520', 'width': 226, 'height': ...
# 5  {'id': 'rm1738270208', 'width': 226, 'height':...
# 6                                               None
# 7  {'id': 'rm2943491328', 'width': 700, 'height':...
# ...
