# %% [markdown]
# <a href="https://colab.research.google.com/github/raj3si/practice-/blob/main/ML_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Steps
#
#
# 1.   Processing + EDA + Feature Selection
#
# 1.   Extract input and output col.
#
# 1.   Scale the values
#
# 1.   Train test split
# 2.   Train the model
#
# 2.   Evaluate the model/model selection
#
# 2.   Deploy model

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df["iq"],c=df["placement"])
plt.show()

# %%
x=df.iloc[:,:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 10   6.0   45.0
# 49   5.4  135.0
# 52   7.0  175.0
# 29   7.0  112.0
# 4    5.8  142.0
# ..   ...    ...
# 50   3.5  233.0
# 30   7.6  128.0
# 36   5.7  140.0
# 70   6.3  127.0
# 51   4.8  141.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 56   6.1   65.0
# 77   7.3   50.0
# 5    7.1   48.0
# 97   6.7  182.0
# 12   5.4  139.0
# 24   4.7  121.0
# 3    7.4  132.0
# 76   4.9  155.0
# 7    5.0   63.0
# 53   8.3  168.0

# %%
y_train
# Out:
# 10    1
# 49    0
# 52    1
# 29    1
# 4     0
#      ..
# 50    0
# 30    1
# 36    0
# 70    1
# 51    0
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 56    0
# 77    1
# 5     1
# 97    1
# 12    0
# 24    0
# 3     1
# 76    0
# 7     0
# 53    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.03744658, -2.07750563],
#        [-0.49468909,  0.26456752],
#        [ 0.92433938,  1.30548893],
#        [ 0.92433938, -0.33396228],
#        [-0.13993197,  0.44672877],
#        [-1.47027117,  1.9560648 ],
#        [ 0.12613586, -1.14067637],
#        [ 0.48089298,  0.9151434 ],
#        [ 1.89992145,  1.07128161],
#        [ 0.12613586,  0.18649842],
#        [ 1.45647506, -0.93249209],
#        [ 0.8356501 , -0.75033085],
#        [-1.736339  , -1.29681458],
#        [-1.11551405, -0.98453816],
#        [-0.67206765,  0.18649842],
#        [ 1.36778578,  0.86309733],
#        [ 1.36778578, -1.66113707],
#        [-0.05124269, -0.49010049],
#        [-0.76075693, -1.5310219 ],
#        [-0.49468909, -0.28191621],
#        [ 1.81123217, -1.19272244],
#        [-0.58337837, -0.09975497],
#        [-0.49468909, -0.46407746],
#        [-0.84944621, -0.17782407],
#        [-1.11551405, -1.89534439],
#        [ 0.48089298,  0.13445235],
#        [-1.20420333,  0.55082091],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.12613586, -1.55704493],
#        [ 1.19040722, -1.94739046],
#        [ 1.01302866, -1.99943653],
#        [ 0.65827154,  1.48765017],
#        [-0.49468909,  0.36865966],
#        [-1.11551405, -0.09975497],
#        [ 1.2790965 ,  0.18649842],
#        [-0.93813549,  0.78502823],
#        [-0.84944621, -1.609091  ],
#        [ 2.07730001,  1.12332768]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
# model training
a=clf.fit(x_train,y_train)

# %%
a
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 1, 0, 0, 1, 0, 0, 1])

# %%
y_test
# Out:
# 56    0
# 77    1
# 5     1
# 97    1
# 12    0
# 24    0
# 3     1
# 76    0
# 7     0
# 53    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
plt.show()

# %%
import pickle

# %%
pickle.dump(clf,open("model.pk1",'wb'))
